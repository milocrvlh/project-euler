# %% [markdown]
# <a href="https://colab.research.google.com/github/CamiloCarvalho/project-euler/blob/main/problem_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def problem_1():
  sum = 0
  for i in range (1000):
    if i % 3 == 0 or i % 5 == 0:
      sum += i
  return sum
print(problem_1())
# Out:
# 233168
